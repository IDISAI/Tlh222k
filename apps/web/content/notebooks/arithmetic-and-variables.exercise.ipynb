# %% [markdown]
# # Exercise: Arithmetic and Variables
#
# In this exercise, you will write your first lines of Python code. Run the setup cell first, then answer each question and call `q<n>.check()` to grade it.

# %%
# Set up the exercise (run this cell first)
from learntools.core import binder
binder.bind(globals())
from learntools.intro_to_programming.ex1 import *
print("Setup complete!")

# %% [markdown]
# ## Question 1
#
# Assign the text `Hello, world!` to a variable named `message`, then run `q1.check()` to grade your answer.

# %%
# TODO: assign the greeting text to `message`
message = ____

print(message)
q1.check()

# %% [markdown]
# ## Question 2
#
# Create a variable `pi` with the value of π rounded to 5 decimal places, then check your answer.

# %%
# TODO: use round(number, 5)
pi = ____

q2.check()

# %% [markdown]
# ## Keep going
#
# Nice work! Head back to the tutorial for the next lesson.
